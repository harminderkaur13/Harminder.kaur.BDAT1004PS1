// %% [markdown]
// # QUESTION 1
// What data type is each of the following?

// %% [markdown]
// # Solution
// |Given||Datatype|
// |-----||--------|
// |5||integer|
// |5.0||float|
// |'5'||string|
// |5>1||boolean|
// |5*2||integer|
// |'5'+'2'||string|
// |'5'*2||string|
// |5/2||float|
// |5//2||integer|
// |[5,2,1]||list|
// |5 in [5,2,1]||boolean|
// |pi(the number)||float|

// %% [markdown]
// # Question 2
// Write (and evaluate) C# expressions that answer these questions:
// # 2 (a)
//  How many letters are there in 'Supercalifragilisticexpialidocious'?

// %% [markdown]
// namespace BDAT1004
// {
//     class Program
//     {
//         static void Main(string[] args)
//         {
//             string i = "Supercalifragilisticexpialidocious";
//             int ilength = i.Length;
//             Console.WriteLine(ilength);
//
//         }
//     }

// %% [markdown]
// ![solution2acd.jpg](attachment:solution2acd.jpg)

// %% [markdown]
// # 2 (b)
// Does 'Supercalifragilisticexpialidocious' contain 'ice' as a substring?

// %% [markdown]
// ## RUNNING IN VISUAL STUDIO
// namespace BDAT1004
// {
//     class program2
//     {
//         static void Main(string[] args)
//         {
//             string i = "Supercalifragilisticexpialidocious";
//             if(i.Contains("ice")==true)
//             Console.WriteLine("ice is contained in the given word");
//             else
//             Console.WriteLine("ice is not contained in the given word");
//
//
//         }
//     }
// }

// %% [markdown]
// ![solution2bcd.jpg](attachment:solution2bcd.jpg)

// %% [markdown]
// #  2(c)
// Which of the following words is the longest:
// Supercalifragilisticexpialidocious, Honorificabilitudinitatibus, or
// Bababadalgharaghtakamminarronnkonn?

// %% [markdown]
// ## RUNNING IN VISUAL STUDIO
// using System;
//
// namespace BDAT1004D2
// {
//     class Program
//     {
//         static void Main(string[] args)
//         {
//             String v1 = "Supercalifragilisticexpialidocious";
//             String V2 = "Honorificabilitudinitatibus";
//             String v3 = "Bababadalgharaghtakamminarronnkonn";
//             int v1length = v1.Length;
//             int v2length = V2.Length;
//             int v3length = v3.Length;
//             if (v1length > v2length)
//             {
//                 if (v1length > v3length)
//                 {
//                     Console.WriteLine("Supercalifragilisticexpialidocious is largest");
//                 }
//                 else
//                 {
//                     Console.WriteLine("Bababadalgharaghtakamminarronnkonn is largest");
//                 }
//
//             }
//             else
//             {
//                 if (v2length > v3length)
//                 { Console.WriteLine("Honorificabilitudinitatibus is largest"); }
//                 else
//                 { Console.WriteLine("Bababadalgharaghtakamminarronnkonn is largest"); }
//
//             }
//         }
//     }
// }

// %% [markdown]
// ## OUTPUT IN VISUAL STUDIO
// ![solutin2dcd.jpg](attachment:solutin2dcd.jpg)

// %% [markdown]
// # 2(d)
// Which composer comes first in the dictionary: 'Berlioz', 'Borodin', 'Brian',
// 'Bartok', 'Bellini', 'Buxtehude', 'Bernstein'. Which one comes last?

// %% [markdown]
// ## RUNNING IN VISUAL STUDIO
// using System;
// using System.Collections.Generic;
//
// namespace bdat10042d
// {
//     public class myDictionary
//     {
//         public static void Main(string[] arg)
//         {
//             Dictionary<string, string> words = new Dictionary<string, string>();
//             words.Add("Berlioz");
//             words.Add("Borodin");
//             words.Add("Brian");
//             words.Add("Bartok");
//             words.Add("Bellin");
//             words.Add("Buxtehude");
//             words.Add("Bernstein");
//
//             foreach (KeyValuePair<string,string> kv in words)
//             { Console.WriteLine(kv.Key +" " + kv.Value); }
//
//         }
//     }
// }

// %% [markdown]
// ![solution2drcd.jpg](attachment:solution2drcd.jpg)

// %% [markdown]
// # Question 3
// Implement function triangleArea(a,b,c) that takes as input the lengths of the 3
// sides of a triangle and returns the area of the triangle. By Heron's formula, the area
// of a triangle with side lengths a, b, and c is
// s(s - a)(s -b)(s -c)
// , where
// s = (a+b+c)/2.

// %% [markdown]
// ## RUNNING IN VISUAL STUDIO
// using System;
//
// namespace bdat10043
// {
//     class Program
//     {
//         static void Main(string[] args)
//         {
//             double a, b, c, s, area;
//             Console.Write("Enter a==");
//             a = double.Parse(Console.ReadLine());
//             Console.Write("Enter b==");
//             b = double.Parse(Console.ReadLine());
//             Console.Write("Enter c==");
//             c = double.Parse(Console.ReadLine());
//             s = (a + b + c) / 2;
//             area = Math.Sqrt(s * (s - a) * (s - b)*(s - c));
//             Console.WriteLine("Area of triangle using herons formula==" + area);
//             Console.ReadLine();
//         }
//     }
// }

// %% [markdown]
// ![solution3cd.jpg](attachment:solution3cd.jpg)

// %% [markdown]
// # Question 4
// Write a program in C# Sharp to separate odd and even integers in separate arrays.

// %% [markdown]
// ## RUNNING IN VISUAL STUDIO
// using System;
//
// namespace bdat10044
// {
//     class Program
//     {
//         static void Main(string[] args)
//         {
//             int e = 0; int o = 0;
//             int[] arr = new int[5];
//             int[] even = new int[5];
//             int[] odd = new int[5];
//
//             arr[0] = 25;
//             arr[1] = 47;
//             arr[2] = 42;
//             arr[3] = 56;
//             arr[4] = 32;
//             for (int a = 0; a < arr.Length; a++)
//             {
//                 if (arr[a] % 2 == 0)
//                 { even[e] = arr[a]; e++; }
//                 else
//                 { odd[o] = arr[a]; o++; }
//             }
//             Console.WriteLine("the even numbers are : ");
//             for (int a = 0; a < e; a++)
//             { Console.WriteLine(even[a]); }
//             Console.WriteLine("the odd numbers are : ");
//             for (int a = 0; a < o; a++)
//             { Console.WriteLine(odd[a]); }
//
//
//         }
//     }
// }

// %% [markdown]
// ![solutionQ4cd.jpg](attachment:solutionQ4cd.jpg)

// %% [markdown]
// # Question 5

// %% [markdown]
// # 5(a)
// Write a function inside(x,y,x1,y1,x2,y2) that returns True or False depending on whether the point (x,y) lies in the rectangle with lower left corner (x1,y1) and upper right corner (x2,y2).

// %% [markdown]
// # RUNNING IN VISUAL STUDIO
// using System;
// namespace rectanglepoints
// {
//     class Rectangle
//     {
//         public bool inside(int x, int y, int x1, int y1, int x2, int y2)
//         {
//
//             if (x >= x1 && x <= x2)
//
//             {
//                 if (y >= y1 && y <= y2)
//                 {
//                     Console.WriteLine("true");
//                 }
//                 else
//                 {
//                     Console.WriteLine("false");
//                 }
//             }
//             else
//             {
//                 Console.WriteLine("false");
//             }
//             return true;
//         }
//         public static void Main()
//         {
//             int a = 0; int b = 0; int c = 0; int d = 0; int e = 0; int f = 0;
//             Console.Write("enter a =");
//             a = Convert.ToInt32(Console.ReadLine());
//             Console.Write("enter b =");
//             b = Convert.ToInt32(Console.ReadLine());
//             Console.Write("enter c =");
//             c = Convert.ToInt32(Console.ReadLine());
//             Console.Write("enter d =");
//             d = Convert.ToInt32(Console.ReadLine());
//             Console.Write("enter e =");
//             e = Convert.ToInt32(Console.ReadLine());
//             Console.Write("enter f =");
//             f = Convert.ToInt32(Console.ReadLine());
//             Rectangle rect = new Rectangle();
//             bool message = rect.inside(a, b, c, d, e, f);
//
//         }
//
//     }
// }

// %% [markdown]
// ![solution5acd.jpg](attachment:solution5acd.jpg)

// %% [markdown]
// # 5(b)
// Use function inside() from part a. to write an expression that tests whether
// the point (1,1) lies in both of the following rectangles: one with lower left
// corner (0.3, 0.5) and upper right corner (1.1, 0.7) and the other with lower
// left corner (0.5, 0.2) and upper right corner (1.1, 2).

// %% [markdown]
// # RUNNING IN VISUAL STUDIO
// using System;
// namespace rectanglepoints
// {
//     class Rectangle
//     {
//         public bool inside(int x, int y, float x1, float y1, float x2, float y2)
//         {
//
//             if (x >= x1 && x <= x2)
//
//             {
//                 if (y >= y1 && y <= y2)
//                 {
//                     if (x >= 0.5 && x <= 1.1)
//                     {
//                         if (y >= 0.2 && y <= 2)
//                         { Console.WriteLine("true"); }
//                         else
//                         { Console.WriteLine("false"); }
//
//                     }
//                     else
//                     { Console.WriteLine("false"); }
//
//                 }
//                 else
//                 {
//                     Console.WriteLine("false");
//                 }
//             }
//             else
//             {
//                 Console.WriteLine("false");
//             }
//             return true;
//         }
//         public static void Main()
//         {
//             int a = 0; int b = 0; float c = 0; float d = 0; float e = 0; float f = 0;
//             Console.Write("enter x =");
//             a = Convert.ToInt32(Console.ReadLine());
//             Console.Write("enter y =");
//             b = Convert.ToInt32(Console.ReadLine());
//             Console.Write("enter x1 =");
//             c = float.Parse(Console.ReadLine());
//             Console.Write("enter x2 =");
//             d = float.Parse(Console.ReadLine());
//             Console.Write("enter y1 =");
//             e = float.Parse(Console.ReadLine());
//             Console.Write("enter y2 =");
//             f = float.Parse(Console.ReadLine());
//             Rectangle rect = new Rectangle();
//             bool message = rect.inside(a, b, c, d, e, f);
//
//         }
//
//     }
// }

// %% [markdown]
// ![solution5bcd.jpg](attachment:solution5bcd.jpg)
